# %%
import ivolatility as ivol
import pandas as pd
import os

ivolApiKey = os.getenv('API_KEY')
ivol.setLoginParams(apiKey=ivolApiKey)

# Let us be interested in call options on "BMW" with expiration dates up to 30 days and delta (Greek) between 0.5 and 0.8 on the date "2025-03-01"
# In this case we need to specify the Region = "Europe" parameter
getOptsData = ivol.setMethod('/equities/eod/stock-opts-by-param')

OptsData = getOptsData(symbol='BMW',startDate='2025-03-01', endDate='2025-03-27',dteFrom=0,dteTo=30,deltaFrom=0.5,deltaTo=0.8,cp='C',region='EUROPE')
OptsData.reset_index(drop=True, inplace=True)

OptsData


# Let's give a similar example, but for the "BMW" put options and this time will use the “moneyness” (out-of-the-money) parameters.
# OptsData = getOptsData(symbol='BMW',startDate='2025-03-01', endDate='2025-03-27',dteFrom=0,dteTo=30,moneynessFrom=-50,moneynessTo=-10,cp='C',region='EUROPE')
# OptsData.reset_index(drop=True, inplace=True)

# OptsData
# Out:
#                     c_date                 option_symbol  dte  stocks_id  \
# 0    2025-03-03 00:00:00.0  BMW 250307C00000810000A.XEUR    4      10466
# 1    2025-03-03 00:00:00.0  BMW 250307C00000820000A.XEUR    4      10466
# 2    2025-03-03 00:00:00.0  BMW 250307C00000830000A.XEUR    4      10466
# 3    2025-03-03 00:00:00.0  BMW 250307C00000840000A.XEUR    4      10466
# 4    2025-03-03 00:00:00.0  BMW 250314C00000790000A.XEUR   11      10466
# ..                     ...                           ...  ...        ...
# 513  2025-03-27 00:00:00.0  BMW 250425C00000730000A.XEUR   29      10466
# 514  2025-03-27 00:00:00.0  BMW 250425C00000740000A.XEUR   29      10466
# 515  2025-03-27 00:00:00.0  BMW 250425C00000750000A.XEUR   29      10466
# 516  2025-03-27 00:00:00.0  BMW 250425C00000760000A.XEUR   29      10466
# 517  2025-03-27 00:00:00.0  BMW 250425C00000770000A.XEUR   29      10466
#
#            expiration_date call_put  price_strike  price_open  price_high  \
# ...
